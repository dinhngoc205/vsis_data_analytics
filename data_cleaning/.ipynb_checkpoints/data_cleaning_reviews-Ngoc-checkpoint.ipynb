# %% [markdown]
# # Datasets
# http://jmcauley.ucsd.edu/data/amazon/
#
# # Data Cleaning Steps:

# %% [markdown]
# The review data is divided in several json files according to the Amazon category of the corresponding products (books, videos, … ). For now, we are going to focus on the Amazon_instant_video category - which is small enough to run on our computers- before extending our analysis to the others. We note that we use the 5-core dataset which means that the original dataset has been reduced so that each of the remaining users and items have 5 reviews each.
#
# We start by downloading the file. Then we store it into a pandas dataframe which will enable us to have a clear overview of the data.

# %% [markdown]
# ## Import data

# %%
from __future__ import absolute_import, division, print_function
from datetime import datetime

from nltk.sentiment.vader import SentimentIntensityAnalyzer
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import gzip

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

ds_folder = "../dataspace/amazon-reviews/"
df = getDF(ds_folder + 'reviews_Cell_Phones_and_Accessories_5.json.gz')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013

# %% [markdown]
# Both the reviewer and the product are identified by codes, respectively `reviewerID` and `asin`.We also have the actual name of the reviewer.
# The text of the reviews as well as the corresponding summaries are represented by strings.
# Each review is characterized by:
# - the name and the id of the reviewer
# - the identification of the product
# - a text and a summary
# - an overall rating score
# - a list of two items giving thethe number of people that found the review usefuland the total number of people who read it.
# - the review time , given both in unix format and as a string.

# %% [markdown]
# ###### Our first step is to change the type of review time to datetime format.

# %%
df.reviewTime=pd.to_datetime(df.reviewTime)

# %%
df.head(5)
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary  unixReviewTime reviewTime
# 0                                 Looks Good      1400630400 2014-05-21
# 1                      Really great product.      1389657600 2014-01-14
# 2                             LOVE LOVE LOVE      1403740800 2014-06-26
# 3                                      Cute!      1382313600 2013-10-21
# 4  leopard home button sticker for iphone 4s      1359849600 2013-02-03

# %% [markdown]
# ### Enrich with new variables
#
# We will now enrich the dataframe with new variables, that we give us a more meaningful insight into the reviews

# %%
df['year']=list(map(lambda x:x.year,df.reviewTime))
df['length_review']=list(map(lambda x:len(x.split(' ')),df.reviewText))

# %%
df.head(5)
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary  unixReviewTime reviewTime  year  \
# 0                                 Looks Good      1400630400 2014-05-21  2014
# 1                      Really great product.      1389657600 2014-01-14  2014
# 2                             LOVE LOVE LOVE      1403740800 2014-06-26  2014
# 3                                      Cute!      1382313600 2013-10-21  2013
# 4  leopard home button sticker for iphone 4s      1359849600 2013-02-03  2013
#
#    length_review
# 0             37
# 1             32
# 2             34
# 3             51
# 4             24

# %% [markdown]
# Instead of keeping a list $[a,b]$ giving the number of people who found the review helpful $(a)$ and total number of people who rated this review as helpful or not $(b)$, we compute a helpfulness score as $\frac{a}{b}$.
# if nobody rated the helpfulness of the review (i.e when $b=0$) we set the score to None.

# %%
l=[]
for i in df.index:
    if df.helpful[i][1]==0:
        l.append(0)
    else:
        l.append(df.helpful[i][0]/df.helpful[i][1])
df['helpfulness']=l

# %%
df.head(5)
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary  unixReviewTime reviewTime  year  \
# 0                                 Looks Good      1400630400 2014-05-21  2014
# 1                      Really great product.      1389657600 2014-01-14  2014
# 2                             LOVE LOVE LOVE      1403740800 2014-06-26  2014
# 3                                      Cute!      1382313600 2013-10-21  2013
# 4  leopard home button sticker for iphone 4s      1359849600 2013-02-03  2013
#
#    length_review  helpfulness
# 0             37     0.000000
# 1             32     0.000000
# 2             34     0.000000
# 3             51     1.000000
# 4             24     0.666667

# %% [markdown]
# ## Clean missing data
# https://machinelearningmastery.com/handle-missing-data-python/

# %% [markdown]
# Having missing values in a dataset can cause errors with some machine learning algorithms.

# %% [markdown]
# #### Check miss values

# %%
df.isnull().sum()
# Out:
# reviewerID           0
# asin                 0
# reviewerName      3519
# helpful              0
# reviewText           0
# overall              0
# summary              0
# unixReviewTime       0
# reviewTime           0
# year                 0
# length_review        0
# helpfulness          0
# dtype: int64

# %% [markdown]
# We notice that some of the reviewer names are missing but since the reviewer Id are available anyway, this is not an issue.

# %% [markdown]
# #### Method 1: Remove Rows With Missing Values

# %% [markdown]
# The simplest strategy for handling missing data is to remove records that contain a missing value.
#
# We can do this by creating a new Pandas DataFrame with the rows containing missing values removed.
#
# Pandas provides the dropna() function that can be used to drop either columns or rows with missing data. We can use dropna() to remove all rows with missing data, as follows:

# %%
df['reviewerName'].dropna()
# Out:
# 0                                 christina
# 1                                  emily l.
# 2                                     Erica
# 3                                        JM
# 4                          patrice m rogoza
# 5                                       RLH
# 6                               Tyler Evans
# 7                          Abdullah Albyati
# 8                                      Adam
# 9                           Agata Majchrzak
# 10                            Alex Maslakov
# 11                                Baja Alan
# 12                            Olivia ysiak
# 13                             Sasha Malkin
# 14                                    tim g
# 15                                Viktoriya
# 16          Zonaldo Reefey "Zonaldo Reefey"
# 17        Alexander Graham Bell Very-Junior
# 18                               amazonfan1
# 19                                   Barbie
# 20            Bernadette Mitchell "Lady Di"
# 21                                      Bob
# 22                              Bruce/Emily
# 23                                  Bryan S
# 24                                    Cathy
# 25                         Daniel Fernandez
# 26                                  DCGeek1
# 27                               Don Powell
# 28                            ebony winslow
# 29                                      Hec
#                         ...
# 194409                                Stina
# 194410                            Tia Scott
# 194411                                 Ever
# 194412                              Natalia
# 194413                            Sasha DLH
# 194414                                Stina
# 194415                            Tia Scott
# 194416                                 Ever
# 194417                                 Jenn
# 194418                                 Nate
# 194419                            Sasha DLH
# 194420                                Stina
# 194421                                 Ever
# 194422                                 Jenn
# 194423                                 Nate
# 194424                            Sasha DLH
# 194425                                Stina
# 194426                                 Ever
# 194427                                 Jenn
# 194428                                 Nate
# 194429                            Sasha DLH
# 194430                                Stina
# 194431     Ann Ingersoll Madison Rain "Ann"
# 194432                              Chuck.C
# 194433                        Dave Edmiston
# 194434                      eyeused2loveher
# 194435                         Jon Davidson
# 194436                    Joyce M. Davidson
# 194437                       Nurse Farrugia
# 194438                       Trisha Crocker
# Name: reviewerName, Length: 190920, dtype: object

# %% [markdown]
# #### Method 2: Impute Missing Values with

# %% [markdown]
# Imputing refers to using a model to replace missing values.
#
# There are many options we could consider when replacing a missing value, for example:
#
# - A constant value that has meaning within the domain, such as 0, distinct from all other values.
# - A value from another randomly selected record.
# - A mean, median or mode value for the column.
# - A value estimated by another predictive model.
#
# Any imputing performed on the training dataset will have to be performed on new data in the future when predictions are needed from the finalized model. This needs to be taken into consideration when choosing how to impute the missing values.
#
# Pandas provides the fillna() function for replacing missing values with a specific value.
#
# For example, we can use fillna() to replace missing values with the "Unknow" for each column, as follows:

# %%
df.isnull().sum()
# Out:
# reviewerID           0
# asin                 0
# reviewerName      3519
# helpful              0
# reviewText           0
# overall              0
# summary              0
# unixReviewTime       0
# reviewTime           0
# year                 0
# length_review        0
# helpfulness          0
# dtype: int64

# %%
df.fillna('Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# reviewerID        0
# asin              0
# reviewerName      0
# helpful           0
# reviewText        0
# overall           0
# summary           0
# unixReviewTime    0
# reviewTime        0
# year              0
# length_review     0
# helpfulness       0
# dtype: int64

# %% [markdown]
# ## Clean malicious data

# %% [markdown]
# ## Clean erroneous data

# %% [markdown]
# #### Check overall must between 0 - 5

# %%
df.loc[(df['overall']<0) & (df['overall']>5)]
# Out:
# Empty DataFrame
# Columns: [reviewerID, asin, reviewerName, helpful, reviewText, overall, summary, unixReviewTime, reviewTime, year, length_review, helpfulness]
# Index: []

# %% [markdown]
# #### reviewTime must be between May 1996 - July 2014

# %%
df.loc[(df['reviewTime']<'1996-05-01') & (df['reviewTime']>'2014-07-31')]
# Out:
# Empty DataFrame
# Columns: [reviewerID, asin, reviewerName, helpful, reviewText, overall, summary, unixReviewTime, reviewTime, year, length_review, helpfulness]
# Index: []

# %%
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary  unixReviewTime reviewTime  year  \
# 0                                 Looks Good      1400630400 2014-05-21  2014
# 1                      Really great product.      1389657600 2014-01-14  2014
# 2                             LOVE LOVE LOVE      1403740800 2014-06-26  2014
# 3                                      Cute!      1382313600 2013-10-21  2013
# 4  leopard home button sticker for iphone 4s      1359849600 2013-02-03  2013
#
#    length_review  helpfulness
# 0             37     0.000000
# 1             32     0.000000
# 2             34     0.000000
# 3             51     1.000000
# 4             24     0.666667

# %% [markdown]
# ## Clean irrelevant data

# %% [markdown]
# The unixReviewTime is the same meaning with reviewTime in datasets, so we will remove this feature.

# %%
del df['unixReviewTime']

# %%
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary reviewTime  year  length_review  \
# 0                                 Looks Good 2014-05-21  2014             37
# 1                      Really great product. 2014-01-14  2014             32
# 2                             LOVE LOVE LOVE 2014-06-26  2014             34
# 3                                      Cute! 2013-10-21  2013             51
# 4  leopard home button sticker for iphone 4s 2013-02-03  2013             24
#
#    helpfulness
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     1.000000
# 4     0.666667

# %% [markdown]
# ## Clean inconsistent data

# %% [markdown]
# #### Sentiment analysis by review

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# import nltk
# nltk.download('vader_lexicon')

sentimentAnalyzer = SentimentIntensityAnalyzer()
sentence = "This camera worked qute well, I am really happy with its image quality and ease-of-use."
sentimentAnalyzer.polarity_scores(sentence)
# Out:
# {'compound': 0.7264, 'neg': 0.0, 'neu': 0.663, 'pos': 0.337}

# %%
df['score_review']=list(map(lambda x:sentimentAnalyzer.polarity_scores(x)['compound'],df.reviewText))
df['score_summary']=list(map(lambda x:sentimentAnalyzer.polarity_scores(x)['compound'],df.summary))

# %%
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...      4.0
# 1  These stickers work like the review says they ...      5.0
# 2  These are awesome and make my phone look so st...      5.0
# 3  Item arrived in great time and was in perfect ...      4.0
# 4  awesome! stays on, and looks great. can be use...      5.0
#
#                                      summary reviewTime  year  length_review  \
# 0                                 Looks Good 2014-05-21  2014             37
# 1                      Really great product. 2014-01-14  2014             32
# 2                             LOVE LOVE LOVE 2014-06-26  2014             34
# 3                                      Cute! 2013-10-21  2013             51
# 4  leopard home button sticker for iphone 4s 2013-02-03  2013             24
#
#    helpfulness  score_review  score_summary
# 0     0.000000       -0.1808         0.4404
# 1     0.000000        0.9403         0.6590
# 2     0.000000        0.8852         0.9274
# 3     1.000000        0.9625         0.5093
# 4     0.666667        0.9020         0.0000

# %%
df.loc[(df['overall']>4) & (df['score_summary']<0)]
# Out:
#             reviewerID        asin  \
# 223      AH0DGDY46OY13  9983798883
# 379     A2PZ6Z9D2CT27P  B00002X29G
# 478     A1Q3B4Q6W4FX46  B0000AKAJL
# 701     A1ATWEANLT57YG  B0002SYC5O
# 707     A2SXHZT52Y6LJ5  B0002WRGH6
# 724     A10TF6TUAV0XZP  B0002WRGHG
# 780     A2Q8J8IL6V9M5T  B000652QNS
# 840     A33FS5H3CPDR6D  B0006FLA80
# 842     A2KTK8C503CYEG  B0006GFARG
# 897     A3T3KPW2QE866W  B0006I2E1O
# 903      AVK9BSXJJ51I8  B0006I2E1O
# 1032    A11FP2U911TTXA  B0007PLXS6
# 780                            K. Lechliter "Walker Boh"    [0, 0]
# 840        Miguel Ali "Film Director & Political Pundit"  [20, 24]
# 842                                              C. Rosa    [2, 4]
# 897                                               leelee  [19, 24]
# 903                                             S. Allen    [0, 0]
# 1032                                            AmanteNJ    [0, 0]
# 1155                                          Weatherman  [11, 11]
# 1295                                              mkanet    [0, 0]
# 1414                                               Dylan    [0, 0]
# 1455                                               ANSSO   [5, 15]
# 1465                                            S. Allen    [0, 0]
# 1550                                            Andytech    [1, 1]
# 1586                                             A. LANE    [0, 0]
# 1615                                              gr8ful  [12, 14]
# 1678                                    PopsSoCal "Pops"    [1, 1]
# 1689                                          Weatherman    [2, 2]
# 1758                                             Mark (.    [0, 0]
# 1764               Dogs & Horses "Spanish Norman Horses"    [1, 2]
# 1808                            Hatchling001 "Hatchling"    [0, 0]
# 1838                                           Penn Name    [0, 0]
# 1948                                              TVDewd    [2, 2]
# 2080    Guy Owen "The older a man gets, the more clea...    [0, 0]
# 2147                                 Science Experiments    [5, 5]
# 2399                                            BigStory    [0, 0]
# ...                                                  ...       ...
# 193022                                    Tasma Buchanan    [0, 0]
# 193058                                    AIMEE A TAYLOR    [0, 0]
# 193270                                        jeff grant    [0, 0]
# 193307                                   Amazon Customer    [1, 2]
# 193492                                  Tony D. Luttrell    [0, 0]
# 193536               shuTTL3bus "shuTTL3bus @gmail .com"    [3, 3]
# 193584                                       Evan Jacobs    [0, 0]
# 193695                                 M. Williams "MBW"    [0, 0]
# 193718                                       Y.Trinh "U"    [0, 0]
# 193729                            Thomas Duff "Duffbert"    [8, 8]
# 193743                                              Lynn    [0, 0]
# 193746                                            Noname    [0, 0]
# 193788                                     Alberto Lasso    [0, 0]
# 193898                  Vicki Montney "neverendingstory"    [0, 0]
# 193943                                   ursula Vincente    [0, 0]
# 193960                         Lisa Kearns "Lisa Kearns"  [17, 22]
# 193993  Zachary S. *Tech Reviewer* "zmanbaseball2@gma...    [1, 1]
# 194032                                    Margaret Picky    [0, 0]
# 194048                                             trebe    [3, 3]
# 194146                                      P. McWhorter    [0, 0]
# 194189                                          Chandler    [0, 0]
# 194206                       Mike Tarrani "Jazz Drummer"    [0, 0]
# 194229                       Mike Tarrani "Jazz Drummer"    [3, 3]
# 194288                                     Alex Maslakov    [0, 0]
# 194293                   Zonaldo Reefey "Zonaldo Reefey"    [0, 0]
# 194313                                              Deon    [0, 0]
# 194405                                         Tia Scott    [0, 0]
# 194422                                              Jenn    [0, 0]
# 194428                                              Nate    [0, 0]
# 194438                                    Trisha Crocker    [0, 0]
#
#                                                reviewText  overall  \
# 223     This charger does the trick.  The charger in m...      5.0
# 379     Great tools, I still use them and I like the q...      5.0
# 478     I bought this to try and repair a POS dash cam...      5.0
# 701     My LG HBS-730 that I use for bike rides with n...      5.0
# 707     I was very happy with my HS820 for the first 3...      5.0
# 724     This headset works fine. It fits perfectly ove...      5.0
# 780     I've been a loyal BoxWave customer for years. ...      5.0
# 840     I am in love with this phone!First off, the Pa...      5.0
# 842     Solid bluetooth headset, particularly consider...      5.0
# 897     I have been a Nextel user for years and their ...      5.0
# 903     If you look carefully at these so called "bad ...      5.0
# 1032    Bought a couple of this for my wife's ipad cau...      5.0
# 1155    IMHO this is slightly better than the Moto H70...      5.0
# 1295    As everyone else says, it sounds very clear, c...      5.0
# 1414    Yea, basically. It's a phone charger for the M...      5.0
# 1455    I bought this phone ofr my in-laws a few month...      5.0
# 1465    Oct 7th 2005If you look carefully at these so ...      5.0
# 1550    I got this headset last week Wednesday and hav...      5.0
# 1586    I bought this phone for the sole purpose of ma...      5.0
# 1615    After ordering the CS55 but before receiving i...      5.0
# 1678    I had a H500 but when it stoped working I went...      5.0
# 1689    IMHO this is slightly better than the Moto HS8...      5.0
# 1758    I received this item on time and in good condi...      5.0
# 1764    We've been using 2 of these batteries for ten ...      5.0
# 1808    Very handy case to keep you valuables or elect...      5.0
# 1838    I have had a few of these (broke them, totally...      5.0
# 1948    This phone does every thing I could want from ...      5.0
# 2080    This does NOT fit the Verizon version of the S...      5.0
# 2147    I was concerned after ordering this device, wh...      5.0
# 2399    Up till last year, I was still fully into one ...      5.0
# ...                                                   ...      ...
# 193022  This case fits my phone great without adding a...      5.0
# 193058  I like the feel of the case. I havent dropped ...      5.0
# 193270  This screen protector was easy to install and ...      5.0
# 193307  I had this same case a year or so ago for the ...      5.0
# 193492  If your like most people you've been somewhere...      5.0
# 193536  What a great idea and cable.  All the cords I ...      5.0
# 193584  This unit works as advertised and doesn't disa...      5.0
# 193695  I love having multiple sync cables, because I ...      5.0
# 193718  Flat wire is nice so it doesn't tangle up. I u...      5.0
# 193729  I've been playing with the stylus pens I recei...      5.0
# 193743  This is the first wall/desktop charger I've us...      5.0
# 193746  If you have an office like mine, the outlet is...      5.0
# 193788  Fully protect your phone all around with this ...      5.0
# 193898  Nice charging box for the price.  Has two slot...      5.0
# 193943  I put this on my daughters phone and loved it....      5.0
# 193960  I received a complimentary Vinsic power bank a...      5.0
# 193993  The Aukey 4.2 amp car charger is a great car c...      5.0
# 194032  This car charger has a 1 1/8 in. square face w...      5.0
# 194048  The TopG USB car charger is a compact device t...      5.0
# 194146  I find that many smartphones can not make it t...      5.0
# 194189  Literally this little speaker can go anywhere-...      5.0
# 194206  This is more of a convenience than a tool for ...      5.0
# 194229  When I received a review sample of this batter...      5.0
# 194288  I dropped my phone 2x on concrete with this ca...      5.0
# 194293  I saw a video of this case in action, and the ...      5.0
# 194313  This dual port USB charger is made for power u...      5.0
# 194405  My daughter is really into animal print so she...      5.0
# 194422  I am not obsessed with this case. I read some ...      5.0
# 194428  I get so many compliments on this case. It was...      5.0
# 194438  product as described, I have wasted a lot of m...      5.0
#
#                                                   summary reviewTime  year  \
# 223                                         Why pay more? 2011-09-18  2011
# 379                                       Not bad quality 2013-03-07  2013
# 478                       Lame attempt to repair a camera 2013-04-19  2013
# 701                                No interference at all 2014-06-26  2014
# 707                              pleased but disappointed 2006-06-25  2006
# 724     Not  sure what all the negative reviews are ab... 2007-01-09  2007
# 780                         Insane Price, BoxWave Quality 2013-05-30  2013
